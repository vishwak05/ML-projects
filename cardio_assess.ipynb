# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/data_cardiovascular_risk.csv')
data.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %%
data.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# min           0.000000      0.000000     0.000000   107.000000    83.50000
# 25%           0.000000      0.000000     0.000000   206.000000   117.00000
# 50%           0.000000      0.000000     0.000000   234.000000   128.50000
# 75%           0.000000      1.000000     0.000000   264.000000   144.00000
# max           1.000000      1.000000     1.000000   696.000000   295.00000
#
#              diaBP          BMI    heartRate      glucose   TenYearCHD
# count  3390.000000  3376.000000  3389.000000  3086.000000  3390.000000
# mean     82.883038    25.794964    75.977279    82.086520     0.150737
# std      12.023581     4.115449    11.971868    24.244753     0.357846
# min      48.000000    15.960000    45.000000    40.000000     0.000000
# 25%      74.500000    23.020000    68.000000    71.000000     0.000000
# 50%      82.000000    25.380000    75.000000    78.000000     0.000000
# 75%      90.000000    28.040000    83.000000    87.000000     0.000000
# max     142.500000    56.800000   143.000000   394.000000     1.000000

# %%
data.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
data.drop(['education','glucose'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   sex              3390 non-null   object
#  3   is_smoking       3390 non-null   object
#  4   cigsPerDay       3368 non-null   float64
#  5   BPMeds           3346 non-null   float64
#  6   prevalentStroke  3390 non-null   int64
#  7   prevalentHyp     3390 non-null   int64
#  8   diabetes         3390 non-null   int64
#  9   totChol          3352 non-null   float64
#  10  sysBP            3390 non-null   float64
#  11  diaBP            3390 non-null   float64
#  12  BMI              3376 non-null   float64
#  13  heartRate        3389 non-null   float64
#  14  TenYearCHD       3390 non-null   int64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 397.4+ KB

# %%
data.isnull().sum()
# Out:
# id                  0
# age                 0
# sex                 0
# is_smoking          0
# cigsPerDay         22
# BPMeds             44
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            38
# sysBP               0
# diaBP               0
# BMI                14
# heartRate           1
# TenYearCHD          0
# dtype: int64

# %%
data.isna().sum()
# Out:
# id                  0
# age                 0
# sex                 0
# is_smoking          0
# cigsPerDay         22
# BPMeds             44
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            38
# sysBP               0
# diaBP               0
# BMI                14
# heartRate           1
# TenYearCHD          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
for i in data.columns:
  if data[i].dtypes=='object':
    print(f'The values of {i} is:\n{data[i].value_counts()}\n\n')
# Out:
# The values of sex is:
# F    1923
# M    1467
# Name: sex, dtype: int64
#
#
# The values of is_smoking is:
# NO     1703
# YES    1687
# Name: is_smoking, dtype: int64

# %%
for i in data.columns:
  if data[i].dtypes!='object':
    print(f'The values of {i} is:\n{data[i].value_counts()}\n\n')
# Out:
# The values of id is:
# 0       1
# 2277    1
# 2253    1
# 2254    1
# 2255    1
#        ..
# 1133    1
# 1134    1
# 1135    1
# 1136    1
# 3389    1
# Name: id, Length: 3390, dtype: int64
#
#
# The values of age is:
# 40    148
# 42    145
# 41    144
# 46    140
# 39    139
# 44    135
# 48    134
# 45    131
# 43    127
# 38    119
# 52    118
# 55    116
# 50    115
# 53    114
# 51    114
# 47    108
# 54    107
# 49    104
# 57     97
# 58     95
# 60     95
# 63     93
# 59     93
# 56     92
# 61     87
# 62     80
# 64     75
# 36     75
# 37     73
# 65     43
# 67     33
# 66     30
# 35     29
# 34     16
# 68     14
# 69      5
# 33      4
# 70      2
# 32      1
# Name: age, dtype: int64
#
#
# The values of cigsPerDay is:
# 0.0     1703
# 20.0     606
# 30.0     176
# 15.0     172
# 10.0     106
# 9.0      104
# 5.0      103
# 3.0       79
# 40.0      62
# 1.0       48
# 25.0      44
# 43.0      42
# 35.0      17
# 2.0       17
# 6.0       14
# 8.0       10
# 7.0        8
# 60.0       8
# 18.0       7
# 4.0        7
# 50.0       6
# 17.0       5
# 23.0       5
# 11.0       4
# 12.0       3
# 13.0       3
# 19.0       2
# 16.0       2
# 45.0       2
# 14.0       1
# 70.0       1
# 38.0       1
# Name: cigsPerDay, dtype: int64
#
#
# The values of BPMeds is:
# 0.0    3246
# 1.0     100
# Name: BPMeds, dtype: int64
#
#
# The values of prevalentStroke is:
# 0    3368
# 1      22
# Name: prevalentStroke, dtype: int64
#
#
# The values of prevalentHyp is:
# 0    2321
# 1    1069
# Name: prevalentHyp, dtype: int64
#
#
# The values of diabetes is:
# 0    3303
# 1      87
# Name: diabetes, dtype: int64
#
#
# The values of totChol is:
# 240.0    65
# 210.0    51
# 220.0    48
# 260.0    46
# 232.0    45
#          ..
# 137.0     1
# 113.0     1
# 392.0     1
# 353.0     1
# 364.0     1
# Name: totChol, Length: 240, dtype: int64
#
#
# The values of sysBP is:
# 110.0    87
# 120.0    85
# 130.0    85
# 125.0    69
# 115.0    68
#          ..
# 214.0     1
# 188.5     1
# 230.0     1
# 169.5     1
# 85.5      1
# Name: sysBP, Length: 226, dtype: int64
#
#
# The values of diaBP is:
# 80.0     213
# 82.0     123
# 70.0     109
# 85.0     107
# 90.0     100
#         ...
# 48.0       1
# 60.5       1
# 129.0      1
# 115.5      1
# 51.0       1
# Name: diaBP, Length: 142, dtype: int64
#
#
# The values of BMI is:
# 22.91    17
# 22.54    16
# 22.19    15
# 23.48    12
# 25.09    12
#          ..
# 19.54     1
# 19.87     1
# 35.01     1
# 21.29     1
# 31.09     1
# Name: BMI, Length: 1259, dtype: int64
#
#
# The values of heartRate is:
# 75.0     442
# 80.0     298
# 70.0     241
# 85.0     191
# 72.0     184
#         ...
# 47.0       1
# 143.0      1
# 51.0       1
# 140.0      1
# 97.0       1
# Name: heartRate, Length: 68, dtype: int64
#
#
# The values of TenYearCHD is:
# 0    2879
# 1     511
# Name: TenYearCHD, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   sex              3390 non-null   object
#  3   is_smoking       3390 non-null   object
#  4   cigsPerDay       3368 non-null   float64
#  5   BPMeds           3346 non-null   float64
#  6   prevalentStroke  3390 non-null   int64
#  7   prevalentHyp     3390 non-null   int64
#  8   diabetes         3390 non-null   int64
#  9   totChol          3352 non-null   float64
#  10  sysBP            3390 non-null   float64
#  11  diaBP            3390 non-null   float64
#  12  BMI              3376 non-null   float64
#  13  heartRate        3389 non-null   float64
#  14  TenYearCHD       3390 non-null   int64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 397.4+ KB

# %%
numeric_features = []
categorical_features=[]
for col in data.columns:
  if data[col].nunique()>10:
    numeric_features.append(col)
  else:
    categorical_features.append(col)
numeric_features.remove('id')
print(f'numeric feature : {numeric_features}')
print(f'category feature : {categorical_features}')
# Out:
# numeric feature : ['age', 'cigsPerDay', 'totChol', 'sysBP', 'diaBP', 'BMI', 'heartRate']
# category feature : ['sex', 'is_smoking', 'BPMeds', 'prevalentStroke', 'prevalentHyp', 'diabetes', 'TenYearCHD']

# %%
plt.figure(figsize=(15,5))
plt.suptitle('Data Distibution of Numeric Features', fontsize=20, fontweight='bold', y=1.02)
for i,col in enumerate(numeric_features):
  plt.subplot(2,4,i+1)
  sns.histplot(data[col])
  plt.xlabel(col)
  plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.suptitle('Outlier Analysis of Numeric Features', fontsize=20, fontweight='bold', y=1.02)
for i,col in enumerate(numeric_features):
  plt.subplot(2, 4, i+1)
  sns.boxplot(data[col])
  plt.xlabel(col)
  plt.tight_layout()

# %%
plt.figure(figsize=(15,5))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', y=1.02)
for i,col in enumerate(categorical_features):
  plt.subplot(2, 4, i+1)
  sns.countplot(data[col])
  plt.xlabel(col)
  plt.tight_layout()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='age', y='heartRate', hue='TenYearCHD', data=data)
plt.title('Heart Disease wrt Age and heartRate')
plt.legend(['Disease', 'No Disease'])

# %%
plt.figure(figsize=(15,5))
plt.suptitle('Bivariate Analysis of Numerical features', fontsize=20, fontweight='bold', y=1.02)
for i,col in enumerate(numeric_features):
  plt.subplot(2, 4, i+1)
  sns.regplot(x=data[col], y='TenYearCHD', data=data)
  plt.xlabel(col)
  plt.tight_layout()

# %%
round(data.isna().sum()/len(data)*100, 2)
# Out:
# id                 0.00
# age                0.00
# sex                0.00
# is_smoking         0.00
# cigsPerDay         0.65
# BPMeds             1.30
# prevalentStroke    0.00
# prevalentHyp       0.00
# diabetes           0.00
# totChol            1.12
# sysBP              0.00
# diaBP              0.00
# BMI                0.41
# heartRate          0.03
# TenYearCHD         0.00
# dtype: float64

# %%
#dropping values with less than 5% of NA values
nan_columns=['cigsPerDay', 'BPMeds', 'totChol', 'BMI', 'heartRate']
data.dropna(subset=nan_columns, inplace=True)

# %%
data.isna().sum()
# Out:
# id                 0
# age                0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# TenYearCHD         0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=data[numeric_features])
plt.show()

# %%
def clip_outliers(data):
    for col in data[numeric_features]:
        # using IQR method to define range of upper and lower limit.
        q1 = data[col].quantile(0.25)
        q3 = data[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        # replacing the outliers with upper and lower bound
        data[col] = data[col].clip(lower_bound, upper_bound)
    return data

# %%
data = clip_outliers(data)

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=data[numeric_features])
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3272 entries, 1 to 3389
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3272 non-null   int64
#  1   age              3272 non-null   int64
#  2   sex              3272 non-null   object
#  3   is_smoking       3272 non-null   object
#  4   cigsPerDay       3272 non-null   float64
#  5   BPMeds           3272 non-null   float64
#  6   prevalentStroke  3272 non-null   int64
#  7   prevalentHyp     3272 non-null   int64
#  8   diabetes         3272 non-null   int64
#  9   totChol          3272 non-null   float64
#  10  sysBP            3272 non-null   float64
#  11  diaBP            3272 non-null   float64
#  12  BMI              3272 non-null   float64
#  13  heartRate        3272 non-null   float64
#  14  TenYearCHD       3272 non-null   int64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 409.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in data.select_dtypes(include="object").columns.tolist():
    data[i] = le.fit_transform(data[i])
data.head()
# Out:
#    id  age  sex  is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 1   1   36    1           0         0.0     0.0                0
# 2   2   46    0           1        10.0     0.0                0
# 3   3   50    1           1        20.0     0.0                0
# 4   4   64    0           1        30.0     0.0                0
# 5   5   61    0           0         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP   diaBP    BMI  heartRate  \
# 1             1         0    212.0  168.0   98.00  29.77       72.0
# 2             0         0    250.0  116.0   71.00  20.35       88.0
# 3             1         0    233.0  158.0   88.00  28.26       68.0
# 4             0         0    241.0  136.5   85.00  26.42       70.0
# 5             1         0    272.0  182.0  113.25  32.80       85.0
#
#    TenYearCHD
# 1           0
# 2           0
# 3           1
# 4           0
# 5           1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3272 entries, 1 to 3389
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3272 non-null   int64
#  1   age              3272 non-null   int64
#  2   sex              3272 non-null   int64
#  3   is_smoking       3272 non-null   int64
#  4   cigsPerDay       3272 non-null   float64
#  5   BPMeds           3272 non-null   float64
#  6   prevalentStroke  3272 non-null   int64
#  7   prevalentHyp     3272 non-null   int64
#  8   diabetes         3272 non-null   int64
#  9   totChol          3272 non-null   float64
#  10  sysBP            3272 non-null   float64
#  11  diaBP            3272 non-null   float64
#  12  BMI              3272 non-null   float64
#  13  heartRate        3272 non-null   float64
#  14  TenYearCHD       3272 non-null   int64
# dtypes: float64(7), int64(8)
# memory usage: 409.0 KB

# %%
data[categorical_features] = data[categorical_features].astype(str)
data.dtypes
# Out:
# id                   int64
# age                  int64
# sex                 object
# is_smoking          object
# cigsPerDay         float64
# BPMeds              object
# prevalentStroke     object
# prevalentHyp        object
# diabetes            object
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# TenYearCHD          object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3272 entries, 1 to 3389
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3272 non-null   int64
#  1   age              3272 non-null   int64
#  2   sex              3272 non-null   object
#  3   is_smoking       3272 non-null   object
#  4   cigsPerDay       3272 non-null   float64
#  5   BPMeds           3272 non-null   object
#  6   prevalentStroke  3272 non-null   object
#  7   prevalentHyp     3272 non-null   object
#  8   diabetes         3272 non-null   object
#  9   totChol          3272 non-null   float64
#  10  sysBP            3272 non-null   float64
#  11  diaBP            3272 non-null   float64
#  12  BMI              3272 non-null   float64
#  13  heartRate        3272 non-null   float64
#  14  TenYearCHD       3272 non-null   object
# dtypes: float64(6), int64(2), object(7)
# memory usage: 409.0+ KB

# %%
plt.figure(figsize=(15,5))
sns.heatmap(data.corr(), annot=True)
# Out:
# <ipython-input-35-2c882edaf9a0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <Axes: >

# %%
def correlation(dataset, threshold):
    col_corr = set()                                           # Set of all the names of correlated features
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:        # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]               # getting the name of column
                col_corr.add(colname)
    return col_corr
correlation(data, 0.7)
# Out:
# <ipython-input-36-ea5601ded910>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = dataset.corr()
# {'diaBP'}

# %%
data['pulse_pressure'] = data['sysBP'] - data['diaBP']
data.drop(columns=['sysBP', 'diaBP'], inplace=True)
data[(data.is_smoking == 'YES') & (data.cigsPerDay == 0)]
data.drop('is_smoking', axis=1, inplace=True)

# %%
plt.figure(figsize=(15,4))
sns.heatmap(data.drop(columns='TenYearCHD').corr(),annot=True)
# Out:
# <ipython-input-38-9f3e6233972b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.drop(columns='TenYearCHD').corr(),annot=True)
# <Axes: >

# %%
X=data.drop(['TenYearCHD'],axis=1)
y=data['TenYearCHD']

# %%
X.head()
# Out:
#    id  age sex  cigsPerDay BPMeds prevalentStroke prevalentHyp diabetes  \
# 1   1   36   1         0.0    0.0               0            1        0
# 2   2   46   0        10.0    0.0               0            0        0
# 3   3   50   1        20.0    0.0               0            1        0
# 4   4   64   0        30.0    0.0               0            0        0
# 5   5   61   0         0.0    0.0               0            1        0
#
#    totChol    BMI  heartRate  pulse_pressure
# 1    212.0  29.77       72.0           70.00
# 2    250.0  20.35       88.0           45.00
# 3    233.0  28.26       68.0           70.00
# 4    241.0  26.42       70.0           51.50
# 5    272.0  32.80       85.0           68.75

# %%
y.head()
# Out:
# 1    0
# 2    0
# 3    1
# 4    0
# 5    1
# Name: TenYearCHD, dtype: object

# %%
X.shape,y.shape
# Out:
# ((3272, 12), (3272,))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=2529)

# %%
print('X_train shape:',X_train.shape)
print('X_test shape:',X_test.shape)
print('y_train shape:',y_train.shape)
print('y_test shape:',y_test.shape)
# Out:
# X_train shape: (2290, 12)
# X_test shape: (982, 12)
# y_train shape: (2290,)
# y_test shape: (982,)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from sklearn.linear_model import LogisticRegression
model1=LogisticRegression(max_iter=8763)
model1.fit(X_train,y_train)
y1_pred=model1.predict(X_test)

# %%
print('Logistic Regression:')
print()
acc1=accuracy_score(y_test,y1_pred)
print('Accuracy score:',acc1)
print()
print('Confusion matrix:\n',confusion_matrix(y_test,y1_pred))
print()
print('Classification report:\n',classification_report(y_test,y1_pred))
# Out:
# Logistic Regression:
#
# Accuracy score: 0.860488798370672
#
# Confusion matrix:
#  [[839   5]
#  [132   6]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       844
#            1       0.55      0.04      0.08       138
#
#     accuracy                           0.86       982
#    macro avg       0.70      0.52      0.50       982
# weighted avg       0.82      0.86      0.81       982

# %%
from sklearn.neighbors import KNeighborsClassifier
model2=KNeighborsClassifier()
model2.fit(X_train,y_train)
y2_pred=model2.predict(X_test)

# %%
print('K Neighbors Classifier:')
print()
acc2=accuracy_score(y_test,y2_pred)
print('Accuracy score:',acc2)
print()
print('Confusion matrix:\n',confusion_matrix(y_test,y2_pred))
print()
print('Classification report:\n',classification_report(y_test,y2_pred))
# Out:
# K Neighbors Classifier:
#
# Accuracy score: 0.8431771894093686
#
# Confusion matrix:
#  [[821  23]
#  [131   7]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       844
#            1       0.23      0.05      0.08       138
#
#     accuracy                           0.84       982
#    macro avg       0.55      0.51      0.50       982
# weighted avg       0.77      0.84      0.80       982

# %%
from sklearn.svm import SVC
model3=SVC()
model3.fit(X_train,y_train)
y3_pred=model3.predict(X_test)

# %%
print('SVM:')
print()
acc3=accuracy_score(y_test,y3_pred)
print('Accuracy score:',accuracy_score(y_test,y3_pred))
print()
print('Confusion matrix:\n',confusion_matrix(y_test,y3_pred))
print()
print('Classification report:\n',classification_report(y_test,y3_pred))
# Out:
# SVM:
#
# Accuracy score: 0.8594704684317719
#
# Confusion matrix:
#  [[844   0]
#  [138   0]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92       844
#            1       0.00      0.00      0.00       138
#
#     accuracy                           0.86       982
#    macro avg       0.43      0.50      0.46       982
# weighted avg       0.74      0.86      0.79       982
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.tree import DecisionTreeClassifier
model4=DecisionTreeClassifier()
model4.fit(X_train,y_train)
y4_pred=model4.predict(X_test)

# %%
print('Decision Tree Classifier:')
print()
acc4=accuracy_score(y_test,y4_pred)
print('Accuracy score:',accuracy_score(y_test,y4_pred))
print()
print('Confusion matrix:\n',confusion_matrix(y_test,y4_pred))
print()
print('Classification report:\n',classification_report(y_test,y4_pred))
# Out:
# Decision Tree Classifier:
#
# Accuracy score: 0.7647657841140529
#
# Confusion matrix:
#  [[713 131]
#  [100  38]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       844
#            1       0.22      0.28      0.25       138
#
#     accuracy                           0.76       982
#    macro avg       0.55      0.56      0.55       982
# weighted avg       0.79      0.76      0.77       982

# %%
from sklearn.naive_bayes import GaussianNB
model5=GaussianNB()
model5.fit(X_train,y_train)
y5_pred=model5.predict(X_test)

# %%
print('GaussianNB:')
print()
acc5=accuracy_score(y_test,y5_pred)
print('Accuracy score:',accuracy_score(y_test,y5_pred))
print()
print('Confusion matrix:\n',confusion_matrix(y_test,y5_pred))
print()
print('Classification report:\n',classification_report(y_test,y5_pred))
# Out:
# GaussianNB:
#
# Accuracy score: 0.8411405295315683
#
# Confusion matrix:
#  [[804  40]
#  [116  22]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       844
#            1       0.35      0.16      0.22       138
#
#     accuracy                           0.84       982
#    macro avg       0.61      0.56      0.57       982
# weighted avg       0.80      0.84      0.81       982

# %%
from sklearn.ensemble import RandomForestClassifier
model6=RandomForestClassifier()
model6.fit(X_train,y_train)
y6_pred=model6.predict(X_test)

# %%
print('Random Forest Classifier:')
print()
acc6=accuracy_score(y_test,y6_pred)
print('Accuracy score:',accuracy_score(y_test,y6_pred))
print()
print('Confusion matrix:\n',confusion_matrix(y_test,y6_pred))
print()
print('Classification report:\n',classification_report(y_test,y6_pred))
# Out:
# Random Forest Classifier:
#
# Accuracy score: 0.8533604887983707
#
# Confusion matrix:
#  [[834  10]
#  [134   4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       844
#            1       0.29      0.03      0.05       138
#
#     accuracy                           0.85       982
#    macro avg       0.57      0.51      0.49       982
# weighted avg       0.78      0.85      0.80       982

# %%
results=pd.DataFrame({
    'Models':['LogisticRegression','KNeighbours','SVM','Decision Tree','GaussianNB','Random Forest'],
    'Score': [acc1*100 , acc2*100 ,acc3*100,acc4*100,acc5*100,acc6*100]}).sort_values(by='Score',ascending=False)
results
# Out:
#                Models      Score
# 0  LogisticRegression  86.048880
# 2                 SVM  85.947047
# 5       Random Forest  85.336049
# 1         KNeighbours  84.317719
# 4          GaussianNB  84.114053
# 3       Decision Tree  76.476578

# %%
results.plot.bar(x='Models',y='Score')
# Out:
# <Axes: xlabel='Models'>
